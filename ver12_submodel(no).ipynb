# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

import numpy as np

from PIL import Image
import os, glob, numpy as np
import pandas as pd
from sklearn import datasets, model_selection
from sklearn.model_selection import train_test_split


USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")

# %%
import random
import numpy as np
import os
import cv2
import glob
from PIL import Image
import PIL.ImageOps    

#다음 변수를 수정하여 새로 만들 이미지 갯수를 정합니다.
num_augmented_images = (825-260)

file_path = './dataset/bad_train/'
file_names = os.listdir(file_path)
total_origin_image_num = len(file_names)
augment_cnt = 1

#for i in range(1, num_augmented_images):
    change_picture_index = random.randrange(1, total_origin_image_num-1)
    print(change_picture_index)
    print(file_names[change_picture_index])
    file_name = file_names[change_picture_index]
    
    origin_image_path = './dataset/bad_train/' + file_name
    image = Image.open(origin_image_path)
    random_augment = random.randrange(1,4)
    
    if(random_augment == 1):
        #이미지 좌우 반전
        print("invert")
        inverted_image = image.transpose(Image.FLIP_LEFT_RIGHT)
        inverted_image.save(file_path + 'inverted_' + str(augment_cnt) + '.jpg')
        
    elif(random_augment == 2):
        #이미지 기울이기
        print("rotate")
        rotated_image = image.rotate(random.randrange(-20, 20))
        rotated_image.save(file_path + 'rotated_' + str(augment_cnt) + '.jpg')
        
    elif(random_augment == 3):
        #노이즈 추가하기
        img = cv2.imread(origin_image_path)
        print("noise")
        row,col,ch= img.shape
        mean = 0
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col,ch))
        gauss = gauss.reshape(row,col,ch)
        noisy_array = img + gauss
        noisy_image = Image.fromarray(np.uint8(noisy_array)).convert('RGB')
        noisy_image.save(file_path + 'noiseAdded_' + str(augment_cnt) + '.jpg')
        
    augment_cnt += 1
# Out:
#   File "<ipython-input-2-41b71315f118>", line 18
#     change_picture_index = random.randrange(1, total_origin_image_num-1)
#     ^
# IndentationError: unexpected indent

# %%
#noisy_image = Image.fromarray(np.uint8(noisy_array)).convert('RGB')

# %%
img_dir = './dataset'
categories = ['bad_train', 'good_train']
np_classes = len(categories)

X = []
y = []

for idx, cat in enumerate(categories):
    
    img_dir_detail = img_dir + "/" + cat
    files = glob.glob(img_dir_detail+"/*.jpg")
    print(cat, " 파일 길이 : ", len(files))
    
    for i, f in enumerate(files):
        try:
            img = Image.open(f)      #폴더를 열어주고 이미지를 읽음
            img = img.convert("RGB")   #RGB로 바꿈
            resize_img = img.resize((128,128)) #이미지 크기를 모두 학습시키기 쉽게 128x128크기
            
            r, g, b = resize_img.split() # 각 쪼갠 이미지를 255로 나눠서 0~1 사이의 값이 나오도록 정규화한다.
            r_resize_img = np.asarray(np.float32(r) / 255.0)
            b_resize_img = np.asarray(np.float32(g) / 255.0)
            g_resize_img = np.asarray(np.float32(b) / 255.0)
            
            rgb_resize_img = np.asarray([r_resize_img, b_resize_img, g_resize_img]) # 이렇게 가공한 이미지를 추가한다.
            
            X.append(rgb_resize_img)
            y.append(idx) # 라벨 (ant: 0, bee: 1)
            if i % 700 == 0: #700으로 하면 폴더 명과 파일 길이를 더 
                print(cat, " : ", f)
        except:
            print(cat, str(i)+" 번째에서 에러 ")


X = np.array(X, dtype='float32')
y = np.array(y, dtype='int64')
print(y)

#1 0  이면 bad
#0 1  이면 good

print("ok", len(y))
# Out:
# bad_train  파일 길이 :  824
# bad_train  :  ./dataset/bad_train/inverted_496.jpg
# bad_train  :  ./dataset/bad_train/b_200.jpg
# good_train  파일 길이 :  825
# good_train  :  ./dataset/good_train/g_418.jpg
# good_train  :  ./dataset/good_train/g_198.jpg
# [0 0 0 ... 1 1 1]
# ok 1649

# %%
X_train = X
y_train = y

# %%
img_dir = './dataset'
categories = ['bad_test', 'good_test']
np_classes = len(categories)

X = []
y = []

for idx, cat in enumerate(categories):
    
    img_dir_detail = img_dir + "/" + cat
    files = glob.glob(img_dir_detail+"/*.jpg")
    print(cat, " 파일 길이 : ", len(files))
    
    for i, f in enumerate(files):
        try:
            img = Image.open(f)      #폴더를 열어주고 이미지를 읽음
            img = img.convert("RGB")   #RGB로 바꿈
            resize_img = img.resize((128,128)) #이미지 크기를 모두 학습시키기 쉽게 128x128크기
            
            r, g, b = resize_img.split() # 각 쪼갠 이미지를 255로 나눠서 0~1 사이의 값이 나오도록 정규화한다.
            r_resize_img = np.asarray(np.float32(r) / 255.0)
            b_resize_img = np.asarray(np.float32(g) / 255.0)
            g_resize_img = np.asarray(np.float32(b) / 255.0)
            
            rgb_resize_img = np.asarray([r_resize_img, b_resize_img, g_resize_img]) # 이렇게 가공한 이미지를 추가한다.
            
            X.append(rgb_resize_img)
            y.append(idx) # 라벨 (ant: 0, bee: 1)
            if i % 700 == 0: #700으로 하면 폴더 명과 파일 길이를 더 
                print(cat, " : ", f)
        except:
            print(cat, str(i)+" 번째에서 에러 ")


X = np.array(X, dtype='float32')
y = np.array(y, dtype='int64')


#1 0  이면 bad
#0 1  이면 good

print("ok", len(y))
# Out:
# bad_test  파일 길이 :  174
# bad_test  :  ./dataset/bad_test/b_302.jpg
# good_test  파일 길이 :  554
# good_test  :  ./dataset/good_test/g_1271.jpg
# ok 728

# %%
X_val, X_test, y_val, y_test = train_test_split(X, y, test_size=0.75, shuffle=True)
#stratify=target

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (1649, 3, 128, 128)
# (182, 3, 128, 128)
# (546, 3, 128, 128)

# %%
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (1649,)
# (182,)
# (546,)

# %%
X_train = torch.from_numpy(X_train).float()
X_val = torch.from_numpy(X_val).float()
X_test = torch.from_numpy(X_test).float()

y_train = torch.from_numpy(y_train).long()
y_val = torch.from_numpy(y_val).long()
y_test = torch.from_numpy(y_test).long()

# %%
#TensorDataset을 DataLoader에 전달해서 데이터의 일부만 간단히 추출
train = TensorDataset(X_train, y_train)
val = TensorDataset(X_val, y_val)
test = TensorDataset(X_test, y_test)

#순서로 섞어서 32개씩 데이터를 변환하는 DataLoader 작성
train_loader = DataLoader(train, batch_size=32, shuffle=True, num_workers = 4)
val_loader = DataLoader(val, batch_size=32, shuffle=False, num_workers = 4)
test_loader = DataLoader(test, batch_size=32, shuffle=False, num_workers = 4)

# %%
print(len(X_train))
print(len(X_val))
print(len(X_test))
# Out:
# 1649
# 182
# 546

# %%
class subNet(nn.Module):
    def __init__(self):
        super(subNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 5, stride=1, padding=(1, 1))
        self.conv2 = nn.Conv2d(32, 64, 5, stride=1, padding=(1, 1))
        self.conv3 = nn.Conv2d(64, 128, 5, stride=1, padding=(1, 1))
        self.conv4 = nn.Conv2d(128, 256, 5, stride=1,padding=(1, 1))
        
        self.pool = nn.MaxPool2d((2, 2), stride=2, dilation=(1, 1))
            
        self.fc1 = nn.Linear(256 * 29 * 29, 512)
        self.fc2 = nn.Linear(512, 2)
            

            
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = self.pool(x)
        #print(x.shape)
        
        x = x.view(x.size(0),-1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


model = subNet().to(DEVICE)

batch_size = 32

# %%
import torch
import torchvision
import torchsummary
model = subNet().to(DEVICE)
print(model)
# Out:
# subNet(
#   (conv1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(128, 256, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=(2, 2), stride=2, padding=0, dilation=(1, 1), ceil_mode=False)
#   (fc1): Linear(in_features=215296, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
from torchsummary import summary
summary(model, input_size=(3,128,128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 126, 126]           2,432
#             Conv2d-2         [-1, 64, 124, 124]          51,264
#          MaxPool2d-3           [-1, 64, 62, 62]               0
#             Conv2d-4          [-1, 128, 60, 60]         204,928
#             Conv2d-5          [-1, 256, 58, 58]         819,456
#          MaxPool2d-6          [-1, 256, 29, 29]               0
#             Linear-7                  [-1, 512]     110,232,064
#             Linear-8                    [-1, 2]           1,026
# ================================================================
# Total params: 111,311,170
# Trainable params: 111,311,170
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 24.99
# Params size (MB): 424.62
# Estimated Total Size (MB): 449.80
# ----------------------------------------------------------------

# %%
# https://hoya012.github.io/blog/DenseNet-Tutorial-2/
num_epoch = 250
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

total = 0
correct = 0
running_loss_history = []
running_correct_history = []
validation_running_loss_history = []
validation_running_correct_history = []


for epoch in range(num_epoch):  
    epoch = epoch+1
    total = 0
    running_correct = 0.0
    running_loss = 0.0
    
    for i, data in enumerate(train_loader, 0):
        X_train, y_train = data
        X_train, y_train = X_train.to(DEVICE), y_train.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() #손실이 갖고 있는 스칼라 값을 가져올 수 있습니다.
       
        _, predicted = torch.max(outputs.data, 1)
        total += y_train.size(0)
        running_correct += (predicted == y_train).sum().item()
       # a = torch.tensor(torch.sum(predicted == y_train).item() / len(predicted))
    
    
    # validation part
    val_total = 0
    validation_running_loss = 0.0
    validation_running_correct = 0.0
    
    for i, data in enumerate(val_loader, 0):
        X_val, y_val = data
        X_val, y_val = X_val.to(DEVICE), y_val.to(DEVICE)
        outputs = model(X_val)
        
        val_loss = criterion(outputs, y_val) 
        validation_running_loss += val_loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        val_total += y_val.size(0)
        validation_running_correct += (predicted == y_val).sum().item()
        
        
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = running_correct / len(train_loader.dataset)
    running_loss_history.append(epoch_loss)
    running_correct_history.append(epoch_acc)

    val_epoch_loss = validation_running_loss / len(val_loader.dataset)
    val_epoch_acc = validation_running_correct / len(val_loader.dataset)
    validation_running_loss_history.append(val_epoch_loss)
    validation_running_correct_history.append(val_epoch_acc)
    
    print(epoch,"epoch")
    print("training loss: {:.5f}, acc: {:5f}".format(epoch_loss, epoch_acc*100))
    print("validation loss: {:.5f}, acc: {:5f}".format(val_epoch_loss, val_epoch_acc*100))
    
    print('---------------------------------------------------------------------') 

print('Finished Training')
# Out:
# 1 epoch
# training loss: 0.02895, acc: 59.733172
# validation loss: 0.01958, acc: 75.824176
# ---------------------------------------------------------------------
# 2 epoch
# training loss: 0.01439, acc: 77.865373
# validation loss: 0.01162, acc: 86.813187
# ---------------------------------------------------------------------
# 3 epoch
# training loss: 0.01317, acc: 80.351728
# validation loss: 0.01180, acc: 86.263736
# ---------------------------------------------------------------------
# 4 epoch
# training loss: 0.01199, acc: 82.716798
# validation loss: 0.01446, acc: 81.868132
# ---------------------------------------------------------------------
# 5 epoch
# training loss: 0.01206, acc: 82.352941
# validation loss: 0.01338, acc: 86.813187
# ---------------------------------------------------------------------
# 6 epoch
# training loss: 0.01204, acc: 81.503942
# validation loss: 0.01275, acc: 85.714286
# ---------------------------------------------------------------------
# 7 epoch
# training loss: 0.01140, acc: 83.020012
# validation loss: 0.01263, acc: 89.010989
# ---------------------------------------------------------------------
# 8 epoch
# training loss: 0.01092, acc: 85.506367
# validation loss: 0.01021, acc: 89.010989
# ---------------------------------------------------------------------
# 9 epoch
# training loss: 0.00999, acc: 85.081868
# validation loss: 0.01137, acc: 86.813187
# ---------------------------------------------------------------------
# 10 epoch
# training loss: 0.00949, acc: 85.748939
# validation loss: 0.01180, acc: 84.615385
# ---------------------------------------------------------------------
# 11 epoch
# training loss: 0.01011, acc: 86.052153
# validation loss: 0.01286, acc: 87.912088
# ---------------------------------------------------------------------
# 12 epoch
# training loss: 0.00956, acc: 85.930867
# validation loss: 0.01077, acc: 88.461538
# ---------------------------------------------------------------------
# 13 epoch
# training loss: 0.00937, acc: 87.689509
# validation loss: 0.01426, acc: 85.164835
# ---------------------------------------------------------------------
# 14 epoch
# training loss: 0.00822, acc: 88.356580
# validation loss: 0.01178, acc: 85.714286
# ---------------------------------------------------------------------
# 15 epoch
# training loss: 0.00678, acc: 90.054579
# validation loss: 0.01229, acc: 85.714286
# ---------------------------------------------------------------------
# 16 epoch
# training loss: 0.00693, acc: 90.721649
# validation loss: 0.01308, acc: 84.615385
# ---------------------------------------------------------------------
# 17 epoch
# training loss: 0.00640, acc: 91.267435
# validation loss: 0.01397, acc: 85.164835
# ---------------------------------------------------------------------
# 18 epoch
# training loss: 0.00614, acc: 91.267435
# validation loss: 0.01043, acc: 89.010989
# ---------------------------------------------------------------------
# 19 epoch
# training loss: 0.00625, acc: 91.388720
# validation loss: 0.01080, acc: 88.461538
# ---------------------------------------------------------------------
# 20 epoch
# training loss: 0.00500, acc: 93.571862
# validation loss: 0.01313, acc: 83.516484
# ---------------------------------------------------------------------
# 21 epoch
# training loss: 0.00411, acc: 94.966646
# validation loss: 0.01306, acc: 87.362637
# ---------------------------------------------------------------------
# 22 epoch
# training loss: 0.00290, acc: 96.422074
# validation loss: 0.01167, acc: 87.912088
# ---------------------------------------------------------------------
# 23 epoch
# training loss: 0.00160, acc: 98.059430
# validation loss: 0.01614, acc: 87.912088
# ---------------------------------------------------------------------
# 24 epoch
# training loss: 0.00174, acc: 97.877502
# validation loss: 0.01415, acc: 89.560440
# ---------------------------------------------------------------------
# 25 epoch
# training loss: 0.00285, acc: 96.422074
# validation loss: 0.01059, acc: 88.461538
# ---------------------------------------------------------------------
# 26 epoch
# training loss: 0.00170, acc: 97.453002
# validation loss: 0.01779, acc: 89.560440
# ---------------------------------------------------------------------
# 27 epoch
# training loss: 0.00270, acc: 96.725288
# validation loss: 0.01095, acc: 86.263736
# ---------------------------------------------------------------------
# 28 epoch
# training loss: 0.00147, acc: 98.423287
# validation loss: 0.01554, acc: 86.263736
# ---------------------------------------------------------------------
# 29 epoch
# training loss: 0.00057, acc: 99.393572
# validation loss: 0.01634, acc: 87.912088
# ---------------------------------------------------------------------
# 30 epoch
# training loss: 0.00080, acc: 99.090358
# validation loss: 0.02472, acc: 87.362637
# ---------------------------------------------------------------------
# 31 epoch
# training loss: 0.00018, acc: 99.818072
# validation loss: 0.01804, acc: 89.010989
# ---------------------------------------------------------------------
# 32 epoch
# training loss: 0.00004, acc: 100.000000
# validation loss: 0.01993, acc: 88.461538
# ---------------------------------------------------------------------
# 33 epoch
# training loss: 0.00001, acc: 100.000000
# validation loss: 0.02033, acc: 88.461538
# ---------------------------------------------------------------------
# 34 epoch
# training loss: 0.00001, acc: 100.000000
# validation loss: 0.02061, acc: 89.010989
# ---------------------------------------------------------------------
# 35 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02102, acc: 88.461538
# ---------------------------------------------------------------------
# 36 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02131, acc: 88.461538
# ---------------------------------------------------------------------
# 37 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02165, acc: 88.461538
# ---------------------------------------------------------------------
# 38 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02187, acc: 88.461538
# ---------------------------------------------------------------------
# 39 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02218, acc: 88.461538
# ---------------------------------------------------------------------
# 40 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02247, acc: 87.912088
# ---------------------------------------------------------------------
# 41 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02268, acc: 87.912088
# ---------------------------------------------------------------------
# 42 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02299, acc: 88.461538
# ---------------------------------------------------------------------
# 43 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02319, acc: 87.912088
# ---------------------------------------------------------------------
# 44 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02345, acc: 87.912088
# ---------------------------------------------------------------------
# 45 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02367, acc: 88.461538
# ---------------------------------------------------------------------
# 46 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02399, acc: 89.010989
# ---------------------------------------------------------------------
# 47 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02424, acc: 89.010989
# ---------------------------------------------------------------------
# 48 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02443, acc: 89.010989
# ---------------------------------------------------------------------
# 49 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02459, acc: 89.010989
# ---------------------------------------------------------------------
# 50 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02481, acc: 89.010989
# ---------------------------------------------------------------------
# 51 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02509, acc: 89.010989
# ---------------------------------------------------------------------
# 52 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02514, acc: 89.560440
# ---------------------------------------------------------------------
# 53 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02538, acc: 89.560440
# ---------------------------------------------------------------------
# 54 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02561, acc: 89.560440
# ---------------------------------------------------------------------
# 55 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02583, acc: 89.560440
# ---------------------------------------------------------------------
# 56 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02609, acc: 89.560440
# ---------------------------------------------------------------------
# 57 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02678, acc: 89.560440
# ---------------------------------------------------------------------
# 58 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02632, acc: 90.109890
# ---------------------------------------------------------------------
# 59 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02718, acc: 90.109890
# ---------------------------------------------------------------------
# 60 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02755, acc: 90.109890
# ---------------------------------------------------------------------
# 61 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02756, acc: 90.109890
# ---------------------------------------------------------------------
# 62 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02795, acc: 90.109890
# ---------------------------------------------------------------------
# 63 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02830, acc: 90.109890
# ---------------------------------------------------------------------
# 64 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02847, acc: 90.109890
# ---------------------------------------------------------------------
# 65 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02821, acc: 90.109890
# ---------------------------------------------------------------------
# 66 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02879, acc: 90.109890
# ---------------------------------------------------------------------
# 67 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02892, acc: 90.109890
# ---------------------------------------------------------------------
# 68 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02879, acc: 90.109890
# ---------------------------------------------------------------------
# 69 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02876, acc: 90.109890
# ---------------------------------------------------------------------
# 70 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02912, acc: 90.109890
# ---------------------------------------------------------------------
# 71 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02918, acc: 90.109890
# ---------------------------------------------------------------------
# 72 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02913, acc: 90.109890
# ---------------------------------------------------------------------
# 73 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02926, acc: 90.109890
# ---------------------------------------------------------------------
# 74 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02913, acc: 90.109890
# ---------------------------------------------------------------------
# 75 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02929, acc: 90.109890
# ---------------------------------------------------------------------
# 76 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02940, acc: 90.659341
# ---------------------------------------------------------------------
# 77 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02935, acc: 90.659341
# ---------------------------------------------------------------------
# 78 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02957, acc: 91.208791
# ---------------------------------------------------------------------
# 79 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02955, acc: 91.208791
# ---------------------------------------------------------------------
# 80 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02967, acc: 90.659341
# ---------------------------------------------------------------------
# 81 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02966, acc: 91.208791
# ---------------------------------------------------------------------
# 82 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02968, acc: 91.208791
# ---------------------------------------------------------------------
# 83 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02989, acc: 91.208791
# ---------------------------------------------------------------------
# 84 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.02989, acc: 91.208791
# ---------------------------------------------------------------------
# 85 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03002, acc: 91.758242
# ---------------------------------------------------------------------
# 86 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03002, acc: 91.208791
# ---------------------------------------------------------------------
# 87 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03014, acc: 91.208791
# ---------------------------------------------------------------------
# 88 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03021, acc: 91.208791
# ---------------------------------------------------------------------
# 89 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03010, acc: 91.758242
# ---------------------------------------------------------------------
# 90 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03028, acc: 91.208791
# ---------------------------------------------------------------------
# 91 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03034, acc: 91.758242
# ---------------------------------------------------------------------
# 92 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03038, acc: 91.208791
# ---------------------------------------------------------------------
# 93 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03035, acc: 91.758242
# ---------------------------------------------------------------------
# 94 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03042, acc: 91.758242
# ---------------------------------------------------------------------
# 95 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03047, acc: 91.758242
# ---------------------------------------------------------------------
# 96 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03059, acc: 91.758242
# ---------------------------------------------------------------------
# 97 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03040, acc: 91.758242
# ---------------------------------------------------------------------
# 98 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03060, acc: 91.758242
# ---------------------------------------------------------------------
# 99 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03070, acc: 91.758242
# ---------------------------------------------------------------------
# 100 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03070, acc: 91.758242
# ---------------------------------------------------------------------
# 101 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03067, acc: 91.758242
# ---------------------------------------------------------------------
# 102 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03060, acc: 91.758242
# ---------------------------------------------------------------------
# 103 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03069, acc: 91.758242
# ---------------------------------------------------------------------
# 104 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03074, acc: 91.758242
# ---------------------------------------------------------------------
# 105 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03076, acc: 91.758242
# ---------------------------------------------------------------------
# 106 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03077, acc: 91.758242
# ---------------------------------------------------------------------
# 107 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03086, acc: 91.758242
# ---------------------------------------------------------------------
# 108 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03089, acc: 91.758242
# ---------------------------------------------------------------------
# 109 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03091, acc: 91.758242
# ---------------------------------------------------------------------
# 110 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03096, acc: 91.758242
# ---------------------------------------------------------------------
# 111 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03093, acc: 91.758242
# ---------------------------------------------------------------------
# 112 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03100, acc: 91.758242
# ---------------------------------------------------------------------
# 113 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03088, acc: 91.758242
# ---------------------------------------------------------------------
# 114 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03093, acc: 91.758242
# ---------------------------------------------------------------------
# 115 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03101, acc: 91.758242
# ---------------------------------------------------------------------
# 116 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03106, acc: 91.758242
# ---------------------------------------------------------------------
# 117 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03108, acc: 91.758242
# ---------------------------------------------------------------------
# 118 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03108, acc: 91.758242
# ---------------------------------------------------------------------
# 119 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03113, acc: 91.758242
# ---------------------------------------------------------------------
# 120 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03108, acc: 92.307692
# ---------------------------------------------------------------------
# 121 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03120, acc: 92.307692
# ---------------------------------------------------------------------
# 122 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03119, acc: 92.307692
# ---------------------------------------------------------------------
# 123 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03129, acc: 92.307692
# ---------------------------------------------------------------------
# 124 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03120, acc: 92.307692
# ---------------------------------------------------------------------
# 125 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03129, acc: 92.307692
# ---------------------------------------------------------------------
# 126 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03129, acc: 92.307692
# ---------------------------------------------------------------------
# 127 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03126, acc: 92.307692
# ---------------------------------------------------------------------
# 128 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03133, acc: 92.307692
# ---------------------------------------------------------------------
# 129 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03146, acc: 92.307692
# ---------------------------------------------------------------------
# 130 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03157, acc: 92.307692
# ---------------------------------------------------------------------
# 131 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03156, acc: 92.307692
# ---------------------------------------------------------------------
# 132 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03172, acc: 92.307692
# ---------------------------------------------------------------------
# 133 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03146, acc: 92.307692
# ---------------------------------------------------------------------
# 134 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03157, acc: 92.307692
# ---------------------------------------------------------------------
# 135 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03164, acc: 92.307692
# ---------------------------------------------------------------------
# 136 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03154, acc: 92.307692
# ---------------------------------------------------------------------
# 137 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03180, acc: 92.307692
# ---------------------------------------------------------------------
# 138 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03169, acc: 92.307692
# ---------------------------------------------------------------------
# 139 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03172, acc: 92.307692
# ---------------------------------------------------------------------
# 140 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03177, acc: 92.307692
# ---------------------------------------------------------------------
# 141 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03181, acc: 92.307692
# ---------------------------------------------------------------------
# 142 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03191, acc: 92.307692
# ---------------------------------------------------------------------
# 143 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03186, acc: 92.307692
# ---------------------------------------------------------------------
# 144 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03191, acc: 92.307692
# ---------------------------------------------------------------------
# 145 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03200, acc: 92.307692
# ---------------------------------------------------------------------
# 146 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03203, acc: 92.307692
# ---------------------------------------------------------------------
# 147 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03190, acc: 92.307692
# ---------------------------------------------------------------------
# 148 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03208, acc: 92.307692
# ---------------------------------------------------------------------
# 149 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03213, acc: 92.307692
# ---------------------------------------------------------------------
# 150 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03202, acc: 92.307692
# ---------------------------------------------------------------------
# 151 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03199, acc: 92.307692
# ---------------------------------------------------------------------
# 152 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03199, acc: 92.307692
# ---------------------------------------------------------------------
# 153 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03192, acc: 92.307692
# ---------------------------------------------------------------------
# 154 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03213, acc: 92.307692
# ---------------------------------------------------------------------
# 155 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03222, acc: 92.307692
# ---------------------------------------------------------------------
# 156 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03217, acc: 92.307692
# ---------------------------------------------------------------------
# 157 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03218, acc: 92.307692
# ---------------------------------------------------------------------
# 158 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03230, acc: 92.307692
# ---------------------------------------------------------------------
# 159 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03229, acc: 92.307692
# ---------------------------------------------------------------------
# 160 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03234, acc: 92.307692
# ---------------------------------------------------------------------
# 161 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03230, acc: 92.307692
# ---------------------------------------------------------------------
# 162 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03238, acc: 92.307692
# ---------------------------------------------------------------------
# 163 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03246, acc: 92.307692
# ---------------------------------------------------------------------
# 164 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03240, acc: 92.307692
# ---------------------------------------------------------------------
# 165 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03257, acc: 92.307692
# ---------------------------------------------------------------------
# 166 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03241, acc: 92.307692
# ---------------------------------------------------------------------
# 167 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03262, acc: 92.307692
# ---------------------------------------------------------------------
# 168 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03256, acc: 92.307692
# ---------------------------------------------------------------------
# 169 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03258, acc: 92.307692
# ---------------------------------------------------------------------
# 170 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03264, acc: 92.307692
# ---------------------------------------------------------------------
# 171 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03262, acc: 92.857143
# ---------------------------------------------------------------------
# 172 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03265, acc: 92.307692
# ---------------------------------------------------------------------
# 173 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03275, acc: 92.857143
# ---------------------------------------------------------------------
# 174 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03280, acc: 92.857143
# ---------------------------------------------------------------------
# 175 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03267, acc: 92.857143
# ---------------------------------------------------------------------
# 176 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03273, acc: 92.857143
# ---------------------------------------------------------------------
# 177 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03283, acc: 92.857143
# ---------------------------------------------------------------------
# 178 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03282, acc: 92.857143
# ---------------------------------------------------------------------
# 179 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03293, acc: 92.857143
# ---------------------------------------------------------------------
# 180 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03291, acc: 92.857143
# ---------------------------------------------------------------------
# 181 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03303, acc: 92.857143
# ---------------------------------------------------------------------
# 182 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03314, acc: 92.857143
# ---------------------------------------------------------------------
# 183 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03323, acc: 92.857143
# ---------------------------------------------------------------------
# 184 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03313, acc: 92.857143
# ---------------------------------------------------------------------
# 185 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03316, acc: 92.857143
# ---------------------------------------------------------------------
# 186 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03309, acc: 92.857143
# ---------------------------------------------------------------------
# 187 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03334, acc: 92.857143
# ---------------------------------------------------------------------
# 188 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03327, acc: 92.857143
# ---------------------------------------------------------------------
# 189 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03332, acc: 92.857143
# ---------------------------------------------------------------------
# 190 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03338, acc: 92.857143
# ---------------------------------------------------------------------
# 191 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03355, acc: 92.857143
# ---------------------------------------------------------------------
# 192 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03343, acc: 92.857143
# ---------------------------------------------------------------------
# 193 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03345, acc: 92.857143
# ---------------------------------------------------------------------
# 194 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03343, acc: 92.857143
# ---------------------------------------------------------------------
# 195 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03346, acc: 92.307692
# ---------------------------------------------------------------------
# 196 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03353, acc: 92.307692
# ---------------------------------------------------------------------
# 197 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03367, acc: 92.307692
# ---------------------------------------------------------------------
# 198 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03376, acc: 92.307692
# ---------------------------------------------------------------------
# 199 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03356, acc: 92.307692
# ---------------------------------------------------------------------
# 200 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03385, acc: 92.307692
# ---------------------------------------------------------------------
# 201 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03396, acc: 92.307692
# ---------------------------------------------------------------------
# 202 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03366, acc: 92.307692
# ---------------------------------------------------------------------
# 203 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03408, acc: 92.307692
# ---------------------------------------------------------------------
# 204 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03402, acc: 92.307692
# ---------------------------------------------------------------------
# 205 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03418, acc: 92.307692
# ---------------------------------------------------------------------
# 206 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03413, acc: 92.307692
# ---------------------------------------------------------------------
# 207 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03393, acc: 92.307692
# ---------------------------------------------------------------------
# 208 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03404, acc: 92.307692
# ---------------------------------------------------------------------
# 209 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03426, acc: 92.307692
# ---------------------------------------------------------------------
# 210 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03416, acc: 92.307692
# ---------------------------------------------------------------------
# 211 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03421, acc: 92.307692
# ---------------------------------------------------------------------
# 212 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03450, acc: 92.307692
# ---------------------------------------------------------------------
# 213 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03413, acc: 92.307692
# ---------------------------------------------------------------------
# 214 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03442, acc: 91.758242
# ---------------------------------------------------------------------
# 215 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03469, acc: 91.758242
# ---------------------------------------------------------------------
# 216 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03428, acc: 91.758242
# ---------------------------------------------------------------------
# 217 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03477, acc: 91.758242
# ---------------------------------------------------------------------
# 218 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03450, acc: 91.758242
# ---------------------------------------------------------------------
# 219 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03457, acc: 91.758242
# ---------------------------------------------------------------------
# 220 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03481, acc: 91.758242
# ---------------------------------------------------------------------
# 221 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03506, acc: 91.758242
# ---------------------------------------------------------------------
# 222 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03495, acc: 91.758242
# ---------------------------------------------------------------------
# 223 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03482, acc: 91.758242
# ---------------------------------------------------------------------
# 224 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03512, acc: 91.758242
# ---------------------------------------------------------------------
# 225 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03544, acc: 91.758242
# ---------------------------------------------------------------------
# 226 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03552, acc: 91.758242
# ---------------------------------------------------------------------
# 227 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03542, acc: 91.758242
# ---------------------------------------------------------------------
# 228 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03596, acc: 91.758242
# ---------------------------------------------------------------------
# 229 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03565, acc: 91.758242
# ---------------------------------------------------------------------
# 230 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03662, acc: 91.758242
# ---------------------------------------------------------------------
# 231 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03629, acc: 91.758242
# ---------------------------------------------------------------------
# 232 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03623, acc: 91.758242
# ---------------------------------------------------------------------
# 233 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03627, acc: 91.758242
# ---------------------------------------------------------------------
# 234 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03651, acc: 91.758242
# ---------------------------------------------------------------------
# 235 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03647, acc: 91.758242
# ---------------------------------------------------------------------
# 236 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03659, acc: 91.758242
# ---------------------------------------------------------------------
# 237 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03703, acc: 91.758242
# ---------------------------------------------------------------------
# 238 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03674, acc: 91.758242
# ---------------------------------------------------------------------
# 239 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03690, acc: 91.758242
# ---------------------------------------------------------------------
# 240 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03754, acc: 91.758242
# ---------------------------------------------------------------------
# 241 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03650, acc: 91.208791
# ---------------------------------------------------------------------
# 242 epoch
# training loss: 0.00000, acc: 100.000000
# validation loss: 0.03771, acc: 91.758242
# ---------------------------------------------------------------------
# 243 epoch
# training loss: 0.05482, acc: 75.621589
# validation loss: 0.02276, acc: 73.626374
# ---------------------------------------------------------------------
# 244 epoch
# training loss: 0.03031, acc: 59.429958
# validation loss: 0.02196, acc: 73.626374
# ---------------------------------------------------------------------
# 245 epoch
# training loss: 0.01804, acc: 67.919951
# validation loss: 0.02117, acc: 76.373626
# ---------------------------------------------------------------------
# 246 epoch
# training loss: 0.01655, acc: 73.377805
# validation loss: 0.02009, acc: 74.175824
# ---------------------------------------------------------------------
# 247 epoch
# training loss: 0.02373, acc: 58.277744
# validation loss: 0.02123, acc: 73.626374
# ---------------------------------------------------------------------
# 248 epoch
# training loss: 0.02042, acc: 60.460885
# validation loss: 0.02097, acc: 73.626374
# ---------------------------------------------------------------------
# 249 epoch
# training loss: 0.01914, acc: 61.613099
# validation loss: 0.02110, acc: 73.626374
# ---------------------------------------------------------------------
# 250 epoch
# training loss: 0.01916, acc: 61.370528
# validation loss: 0.02107, acc: 73.626374
# ---------------------------------------------------------------------
# Finished Training

# %%
import matplotlib.pyplot as plt
def plot_acc(train_losses, valid_losses):
    '''
    training과 validation loss를 시각화하는 함수
    '''
    
    # plot style을 seaborn으로 설정
    plt.style.use('seaborn')
    
    train_losses = np.array(train_losses) 
    valid_losses = np.array(valid_losses)

    fig, ax = plt.subplots(figsize = (8, 4.5))

    ax.plot(train_losses, color='blue', label='Training accuracy') 
    ax.plot(valid_losses, color='red', label='Validation accuracy')
    ax.set(title="Accuracy over epochs", 
            xlabel='Epoch',
            ylabel='Accuracy') 
    ax.legend()
    fig.show()
    
    # plot style을 기본값으로 설정
    plt.style.use('default')

# %%
def plot_loss(train_losses, valid_losses):
    '''
    training과 validation loss를 시각화하는 함수
    '''
    
    # plot style을 seaborn으로 설정
    plt.style.use('seaborn')

    train_losses = list(np.array(train_losses))
    valid_losses = list(np.array(valid_losses))

    fig, ax = plt.subplots(figsize = (8, 4.5))

    ax.plot(train_losses, color='blue', label='Training loss') 
    ax.plot(valid_losses, color='red', label='Validation loss')
    ax.set(title="Loss over epochs", 
            xlabel='Epoch',
            ylabel='Loss') 
    ax.legend()
    fig.show()
    
    # plot style을 기본값으로 설정
    plt.style.use('default')

# %%
plot_acc(running_correct_history, validation_running_correct_history)

# %%
plot_loss(running_loss_history, validation_running_loss_history)

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

for epoch in range(num_epoch): 

    correct = 0
    total = 0
    test_loss = 0.0

    with torch.no_grad():
        for data in test_loader:
            X_test, y_test = data
            X_test, y_test = X_test.to(DEVICE), y_test.to(DEVICE)
            outputs = model(X_test)
            
            
            test_loss += F.cross_entropy(outputs, y_test, reduction='sum').item()
            
            _, predicted = torch.max(outputs, 1)
            c = (predicted == y_test).squeeze()
            
            for i in range(y_test.shape[0]):
                label = y_test[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1
            
                total += y_test.size(0)
                correct += (predicted == y_test).sum().item()
                
            
        test_loss /= len(test_loader.dataset)
        print('[%d epoch] Test Accuracy: %d %%' % (epoch + 1, 100 * correct / total),', Loss:{:.4f}'.format(test_loss))
        print("Test Accuracy Accuracy : {:.5f}".format( 100 * correct / total))
                      

   
print('Accuracy of the network on the 1813 test images: %d %%' % (
    100 * correct / total)) 

for i in range(2):
    print('Accuracy of %5s : %2d %%' % (
        categories[i], 100 * class_correct[i] / class_total[i]))
# Out:
# [1 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [2 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [3 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [4 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [5 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [6 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [7 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [8 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [9 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [10 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [11 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [12 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [13 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [14 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [15 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [16 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [17 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [18 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [19 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [20 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [21 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [22 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [23 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [24 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [25 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [26 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [27 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [28 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [29 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [30 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [31 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [32 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [33 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [34 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [35 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [36 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [37 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [38 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [39 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [40 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [41 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [42 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [43 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [44 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [45 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [46 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [47 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [48 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [49 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [50 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [51 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [52 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [53 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [54 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [55 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [56 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [57 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [58 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [59 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [60 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [61 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [62 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [63 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [64 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [65 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [66 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [67 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [68 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [69 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [70 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [71 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [72 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [73 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [74 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [75 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [76 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [77 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [78 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [79 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [80 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [81 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [82 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [83 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [84 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [85 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [86 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [87 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [88 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [89 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [90 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [91 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [92 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [93 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [94 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [95 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [96 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [97 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [98 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [99 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [100 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [101 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [102 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [103 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [104 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [105 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [106 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [107 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [108 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [109 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [110 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [111 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [112 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [113 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [114 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [115 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [116 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [117 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [118 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [119 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [120 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [121 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [122 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [123 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [124 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [125 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [126 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [127 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [128 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [129 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [130 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [131 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [132 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [133 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [134 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [135 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [136 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [137 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [138 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [139 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [140 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [141 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [142 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [143 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [144 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [145 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [146 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [147 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [148 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [149 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [150 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [151 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [152 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [153 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [154 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [155 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [156 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [157 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [158 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [159 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [160 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [161 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [162 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [163 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [164 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [165 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [166 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [167 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [168 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [169 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [170 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [171 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [172 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [173 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [174 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [175 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [176 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [177 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [178 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [179 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [180 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [181 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [182 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [183 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [184 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [185 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [186 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [187 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [188 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [189 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [190 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [191 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [192 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [193 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [194 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [195 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [196 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [197 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [198 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [199 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [200 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [201 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [202 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [203 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [204 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [205 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [206 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [207 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [208 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [209 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [210 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [211 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [212 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [213 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [214 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [215 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [216 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [217 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [218 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [219 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [220 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [221 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [222 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [223 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [224 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [225 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [226 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [227 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [228 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [229 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [230 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [231 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [232 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [233 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [234 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [235 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [236 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [237 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [238 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [239 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [240 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [241 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [242 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [243 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [244 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [245 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [246 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [247 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [248 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [249 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# [250 epoch] Test Accuracy: 76 % , Loss:0.6277
# Test Accuracy Accuracy : 76.84356
# Accuracy of the network on the 1813 test images: 76 %
# Accuracy of bad_test :  0 %
# Accuracy of good_test : 100 %

# %%
from ignite.metrics import Accuracy, Precision, Recall

def thresholded_output_transform(output):
    y_pred, y = output
    y_pred = torch.round(y_pred)
    return y_pred, y

binary_accuracy = Accuracy(thresholded_output_transform)
precision = Precision(thresholded_output_transform)
recall = Recall(thresholded_output_transform)

# %%
def CalculateMetrics(model):
    with torch.no_grad():
        for images, labels in test_loader:
            if USE_CUDA:
                images, labels = images.cuda(), labels.cuda()
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            binary_accuracy.update((predicted, labels))
            precision.update((predicted, labels))
            recall.update((predicted, labels))
            
        print('Model accuracy : ', binary_accuracy.compute())
        print('Model Precision : ', precision.compute().item())
        print('Model Recall : ', recall.compute().item())

# %%
CalculateMetrics(model)
# Out:
# Model accuracy :  0.7692307692307693
# Model Precision :  0.7692307692307693
# Model Recall :  1.0

# %%
def CalculateMetrics(model):
    with torch.no_grad():
        for images, labels in test_loader:
            if USE_CUDA:
                images, labels = images.cuda(), labels.cuda()
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            binary_accuracy.update((predicted, labels))
            precision.update((predicted, labels))
            recall.update((predicted, labels))
            
        print('Model accuracy : ', binary_accuracy.compute())
        print('Model Precision : ', precision.compute().item())
        print('Model Recall : ', recall.compute().item())

# %%
F1 = (precision * recall * 2 / (precision + recall)).mean()
